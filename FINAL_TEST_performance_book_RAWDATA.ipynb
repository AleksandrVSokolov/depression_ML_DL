# %% [markdown]
# ### Final test performance of ML classifiers

# %%
import os
import pandas
from HelperScriptsPY.helper_functions import drop_useless_column

base_dir = "ML_CV_and_FINAL_RAW/FINAL_TEST_ML"

os.makedirs("RESULTS_FINAL_TEST_RAWDATA", exist_ok=True)

subfolders = [base_dir + "/" + x for x in os.listdir(base_dir) if os.path.isdir(base_dir + "/" + x)]

performance_lists = []
for subfolder in subfolders:
    path = subfolder + "/" + "fold_FINAL_TEST_model_performance.csv"
    dataset = pandas.read_csv(path)
    dataset = drop_useless_column(dataset)
    dataset["path"] = path
    performance_lists.append(dataset)

performance_df = pandas.concat(performance_lists)
performance_df = performance_df.sort_values(by=["model"], ascending=False)
performance_df.to_csv("RESULTS_FINAL_TEST_RAWDATA/FINAL_TEST_ML.csv")
performance_df
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# ...

# %% [markdown]
# ### Final test performance for 10K CpGs (penalized regressions)

# %%
import os
import pandas
from HelperScriptsPY.helper_functions import drop_useless_column

base_dir = "ML_CV_and_FINAL_RAW/FINAL_TEST_ML_10K"

os.makedirs("RESULTS_FINAL_TEST_RAWDATA", exist_ok=True)

subfolders = [base_dir + "/" + x for x in os.listdir(base_dir) if os.path.isdir(base_dir + "/" + x)]
subfolders = [path + "/" + x for path in subfolders for x in os.listdir(path)]

performance_lists = []
for subfolder in subfolders:
    path = subfolder + "/" + "fold_FINAL_TEST_model_performance.csv"
    dataset = pandas.read_csv(path)
    dataset = drop_useless_column(dataset)
    dataset["path"] = path
    performance_lists.append(dataset)

performance_df = pandas.concat(performance_lists)
performance_df = performance_df.sort_values(by=["model"], ascending=False)
performance_df["cpg_type"] = "Top 10K Limma"
performance_df.to_csv("RESULTS_FINAL_TEST_RAWDATA/FINAL_TEST_ML_10K.csv")
performance_df
# Out:
#                     model        fold  total_folds     mval       cpg_type
# 0       RidgeLogisticRegr  FINAL_TEST            3     Mval  Top 10K Limma  \
# 0       RidgeLogisticRegr  FINAL_TEST            3  Betaval  Top 10K Limma
# 0        Lasso_classifier  FINAL_TEST            3  Betaval  Top 10K Limma
# 0        Lasso_classifier  FINAL_TEST            3     Mval  Top 10K Limma
# 0  Elastic_net_classifier  FINAL_TEST            3     Mval  Top 10K Limma
# 0  Elastic_net_classifier  FINAL_TEST            3  Betaval  Top 10K Limma
#
#    limma_features  accuracy_train  accuracy_test  auc_train  auc_test
# 0           10000        1.000000       0.556962   1.000000  0.544870  \
# 0           10000        0.993850       0.613924   0.999054  0.725073
# 0           10000        0.923739       0.588608   0.980723  0.699514
# 0           10000        0.999385       0.667722   0.999997  0.725234
# 0           10000        0.999385       0.658228   1.000000  0.724350
# ...

# %% [markdown]
# ### Final test performance Small DNN classifiers

# %%
import os
import pandas
from HelperScriptsPY.helper_functions import drop_useless_column

base_dir = "FINAL_TEST_DNN_RAW/SmallDNN"

os.makedirs("RESULTS_FINAL_TEST_RAWDATA", exist_ok=True)

subfolders = [base_dir + "/" + x for x in os.listdir(base_dir) if os.path.isdir(base_dir + "/" + x)]

performance_lists = []
for subfolder in subfolders:
    path = subfolder + "/" + "fold_FINAL_TEST_model_performance.csv"
    dataset = pandas.read_csv(path)
    dataset = drop_useless_column(dataset)
    dataset["path"] = path
    performance_lists.append(dataset)

performance_df = pandas.concat(performance_lists)
performance_df = performance_df.sort_values(by=["model"], ascending=False)
performance_df["model"] = "DNN classifier"
performance_df.to_csv("RESULTS_FINAL_TEST_RAWDATA/FINAL_TEST_SmallDNN.csv")
performance_df
# Out:
#             model  epochs        fold  total_folds  batch_size  mval
# 0  DNN classifier    1000  FINAL_TEST            3         128  Mval  \
# 0  DNN classifier    1000  FINAL_TEST            3         128  Mval
#
#                           cpg_type  limma_features outer_cls_activ inner_act
# 0  Top_200_all_consistent_CpGs.txt             200         sigmoid      relu  \
# 0                              ALL             200         sigmoid      relu
#
#    learning_rate     classif_loss_fun  train_classification_loss
# 0         0.0001  binary_crossentropy                   0.012127  \
# 0         0.0001  binary_crossentropy                   0.014402
#
#    test_classification_loss  accuracy_train  accuracy_test  auc_train
# 0                  1.335332        0.998155       0.702532   0.999997  \
# 0                  1.461707        0.998770       0.696203   0.999989
#
#    auc_test  roc_auc_plot_test
# 0  0.786481           0.786481  \
# 0  0.743962           0.743962
#
# ...

# %% [markdown]
# ### Final test performance (JointAE-classifier)

# %%
import os
import pandas
from HelperScriptsPY.helper_functions import drop_useless_column

base_dir = "FINAL_TEST_DNN_RAW/JointAE"

os.makedirs("RESULTS_FINAL_TEST_RAWDATA", exist_ok=True)

subfolders = [base_dir + "/" + x for x in os.listdir(base_dir) if os.path.isdir(base_dir + "/" + x)]

performance_lists = []
for subfolder in subfolders:
    path = subfolder + "/" + "fold_FINAL_TEST_model_performance.csv"
    dataset = pandas.read_csv(path)
    dataset = drop_useless_column(dataset)
    dataset["path"] = path
    performance_lists.append(dataset)

performance_df = pandas.concat(performance_lists)
performance_df = performance_df.sort_values(by=["model"], ascending=False)
performance_df["model"] = "JointAE-classifier"
performance_df.to_csv("RESULTS_FINAL_TEST_RAWDATA/FINAL_TEST_JointAE.csv")
performance_df
# Out:
#                 model  epochs        fold  total_folds  batch_size  mval
# 0  JointAE-classifier    2000  FINAL_TEST            3         128  Mval  \
# 0  JointAE-classifier    2000  FINAL_TEST            3         128  Mval
#
#    balance_alpha                         cpg_type  limma_features
# 0            0.1                              ALL             200  \
# 0            0.1  Top_200_all_consistent_CpGs.txt             200
#
#   outer_cls_activ  ... train_recon_loss test_recon_loss
# 0         sigmoid  ...         0.133249        0.148856  \
# 0         sigmoid  ...         0.186603        0.254755
#
#    train_classification_loss  test_classification_loss accuracy_train
# 0                   0.271433                  0.923976       0.915129  \
# 0                   0.154422                  0.600408       0.963715
#
#   accuracy_test auc_train  auc_test  roc_auc_plot_test
# 0      0.642405  0.927243  0.592051           0.592051  \
# ...

# %% [markdown]
# ### Final test performance (JointVAE-classifier)

# %%
import os
import pandas
from HelperScriptsPY.helper_functions import drop_useless_column

base_dir = "FINAL_TEST_DNN_RAW/JointVAE"

os.makedirs("RESULTS_FINAL_TEST_RAWDATA", exist_ok=True)

subfolders = [base_dir + "/" + x for x in os.listdir(base_dir) if os.path.isdir(base_dir + "/" + x)]

performance_lists = []
for subfolder in subfolders:
    path = subfolder + "/" + "fold_FINAL_TEST_model_performance.csv"
    dataset = pandas.read_csv(path)
    dataset = drop_useless_column(dataset)
    dataset["path"] = path
    performance_lists.append(dataset)

performance_df = pandas.concat(performance_lists)
performance_df = performance_df.sort_values(by=["model"], ascending=False)
performance_df["model"] = "JointVAE-classifier"
performance_df.to_csv("RESULTS_FINAL_TEST_RAWDATA/FINAL_TEST_JointVAE.csv")
performance_df
# Out:
#                  model  epochs        fold  total_folds  batch_size  mval
# 0  JointVAE-classifier    2250  FINAL_TEST            3         128  Mval  \
# 0  JointVAE-classifier    2250  FINAL_TEST            3         128  Mval
#
#    balance_alpha                         cpg_type  limma_features
# 0            1.0                              ALL             200  \
# 0            1.0  Top_200_all_consistent_CpGs.txt             200
#
#   outer_cls_activ  ... train_classification_loss test_classification_loss
# 0            tanh  ...                  0.333263                 1.442036  \
# 0            tanh  ...                  0.184757                 1.027054
#
#    train_kl_loss  test_kl_loss accuracy_train accuracy_test auc_train
# 0       0.131191      0.131717       0.906519      0.617089  0.952312  \
# 0       0.128501      0.163652       0.945879      0.727848  0.969590
#
#    auc_test  roc_auc_plot_test
# 0  0.736366           0.736366  \
# 0  0.798979           0.798979
#
# ...

# %% [markdown]
# ### Merge result files

# %%
import os
import pandas
import re
from HelperScriptsPY import helper_functions

base_dir = "RESULTS_FINAL_TEST_RAWDATA"
ml_files = [base_dir + "/" + x for x in os.listdir(base_dir) if not re.search(".xlsx", x)]

merged_files = []

for x in ml_files:
    dataset = pandas.read_csv(x)
    dataset = helper_functions.drop_useless_column(dataset)
    dataset.replace({
        'model': {
            "SVM_c_RBF_15": "SVM (RBF kernel)",
            "SVM_c": "SVM (Linear kernel)",
            "RidgeLogisticRegr": "Logistic regression ('L2')",
            "RandomForest": "Random forest",
            "LogisticRegr": "Logistic regression (no regularization)",
            "Lasso_classifier": "Logistic regression ('L1')",
            "Elastic_net_classifier": "Logistic regression ('L1L2'/Elastic net)",
            "DecisionTree": "Decision tree"},
            'cpg_type': {
            "ALL":"Top 200 Limma",
            "Top_200_all_consistent_CpGs.txt": "Top 200 Consistent (Pre-selected)"}
    }, inplace=True)
    dataset = dataset[["model", 
                       "mval",
                       "accuracy_train",
                       "accuracy_test",
                       "auc_train",
                       "auc_test",
                       "cpg_type"]]
    merged_files.append(dataset)
merged_files = pandas.concat(merged_files)
merged_files.columns = ["Model", 
                        "Methylation value", 
                        "Accuracy (train/CV data)", 
                        "Accuracy (last hold-out)", 
                        "AUC (train/CV data)",
                        "AUC (last hold-out)",
                        "Selected CpGs (features)"]
merged_files = merged_files.reset_index(drop=True)
merged_files.loc[:, merged_files.dtypes != "object"] = merged_files.loc[:, merged_files.dtypes != "object"].round(decimals=3)
merged_files = merged_files.sort_values(by=["Selected CpGs (features)", "Model"], ascending=True)
merged_files.to_excel("RESULTS_FINAL_TEST_RAWDATA/Model_performance_final_test.xlsx", index=False)
merged_files
# Out:
#                                        Model Methylation value
# 44                Logistic regression ('L1')           Betaval  \
# 45                Logistic regression ('L1')              Mval
# 46  Logistic regression ('L1L2'/Elastic net)              Mval
# 47  Logistic regression ('L1L2'/Elastic net)           Betaval
# 42                Logistic regression ('L2')              Mval
# 43                Logistic regression ('L2')           Betaval
# 38                                  AdaBoost           Betaval
# 39                                  AdaBoost              Mval
# 40                            DNN classifier              Mval
# 33                             Decision tree              Mval
# 34                             Decision tree           Betaval
# 3                         JointAE-classifier              Mval
# 1                        JointVAE-classifier              Mval
# 24                Logistic regression ('L1')           Betaval
# ...

# %%
# Produce final result
CV_results = pandas.read_excel("10_CV_Results_RAWDATA/Model_performance_10CV_RAWDATA.xlsx")
Final_test_results = pandas.read_excel("RESULTS_FINAL_TEST_RAWDATA/Model_performance_final_test.xlsx")

with pandas.ExcelWriter("Model_performances_rawdata.xlsx") as writer:
   
    # use to_excel function and specify the sheet_name and index 
    # to store the dataframe in specified sheet
    CV_results.to_excel(writer, sheet_name="10CV (Cohort norm)", index=False)
    Final_test_results.to_excel(writer, sheet_name="Final test (Cohort norm)", index=False)

# %% [markdown]
# ### Generate AUC figures for final tests

# %%
import os
import pandas
import re
from HelperScriptsPY import helper_functions

base_dir = "RESULTS_FINAL_TEST_RAWDATA"
ml_files = [base_dir + "/" + x for x in os.listdir(base_dir) if not re.search(".xlsx", x)]

merged_files = []

for x in ml_files:
    dataset = pandas.read_csv(x)
    dataset = helper_functions.drop_useless_column(dataset)
    dataset.replace({
        'model': {
            "SVM_c_RBF_15": "SVM (RBF kernel)",
            "SVM_c": "SVM (Linear kernel)",
            "RidgeLogisticRegr": "Logistic regression ('L2')",
            "RandomForest": "Random forest",
            "LogisticRegr": "Logistic regression (no regularization)",
            "Lasso_classifier": "Logistic regression ('L1')",
            "Elastic_net_classifier": "Logistic regression ('L1L2'/Elastic net)",
            "DecisionTree": "Decision tree"},
            'cpg_type': {
            "ALL":"Top 200 Limma",
            "Top_200_all_consistent_CpGs.txt": "Top 200 Consistent (Pre-selected)"}
    }, inplace=True)
    dataset = dataset[["model", 
                       "mval",
                       "accuracy_train",
                       "accuracy_test",
                       "auc_train",
                       "auc_test",
                       "cpg_type",
                       "path"]]
    merged_files.append(dataset)
merged_files = pandas.concat(merged_files)
merged_files.loc[:, merged_files.dtypes != "object"] = merged_files.loc[:, merged_files.dtypes != "object"].round(decimals=3)

# Selecting only betas for models (except for VAE)
merged_files = merged_files[merged_files["mval"] == "Mval"]
merged_files.reset_index(inplace=True, drop=True)
for i in range(merged_files.shape[0]):
    if merged_files["cpg_type"].values[i] == "Top 10K Limma":
        merged_files.loc[i, ("model")] = merged_files.loc[i, ("model")] + " 10K"
        
merged_files_limma = merged_files[merged_files["cpg_type"].isin(["Top 200 Limma", "Top 10K Limma"])]
merged_files_bias = merged_files[~merged_files["cpg_type"].isin(["Top 200 Limma", "Top 10K Limma"])]
merged_files_bias
# Out:
#                                        model  mval  accuracy_train
# 1                        JointVAE-classifier  Mval           0.946  \
# 3                         JointAE-classifier  Mval           0.964
# 5                           SVM (RBF kernel)  Mval           0.913
# 6                        SVM (Linear kernel)  Mval           0.838
# 8                 Logistic regression ('L2')  Mval           0.836
# 11                             Random forest  Mval           1.000
# 13   Logistic regression (no regularization)  Mval           0.835
# 15                Logistic regression ('L1')  Mval           0.823
# 17  Logistic regression ('L1L2'/Elastic net)  Mval           0.823
# 19                             Decision tree  Mval           1.000
# 21                                  AdaBoost  Mval           0.817
# 22                            DNN classifier  Mval           0.998
#
#     accuracy_test  auc_train  auc_test                           cpg_type
# ...

# %%
# Code to make ROC curve for biased feature models
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (positive bias, non-harmonized data)')
for i in range(merged_files_bias.shape[0]):
    path = merged_files_bias.path.values[i]
    path = path.split("/")
    path = path[0:(len(path)-1):1]
    path = '/'.join(path)
    tpr_file = [path + "/" + file for file in os.listdir(path) if re.search("_tpr_test", file)]
    fpr_file = [path + "/" + file for file in os.listdir(path) if re.search("_fpr_test", file)]

    fpr = pandas.read_csv(fpr_file[0], header=None)
    tpr = pandas.read_csv(tpr_file[0], header=None)

    fpr = helper_functions.drop_useless_column(fpr)
    tpr = helper_functions.drop_useless_column(tpr)

    auc = merged_files_bias.auc_test.values[i]
    model = merged_files_bias.model.values[i]

    plt.plot(fpr[1], tpr[1], label= f"{model} ({auc})")
plt.legend(loc='best')
plt.savefig("ROC_curve_final_test_bias_raw.pdf", dpi=300)

# %%
# Code to make ROC curve for Limma-based feature models
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (non-harmonized data)')
for i in range(merged_files_limma.shape[0]):
    path = merged_files_limma.path.values[i]
    path = path.split("/")
    path = path[0:(len(path)-1):1]
    path = '/'.join(path)
    tpr_file = [path + "/" + file for file in os.listdir(path) if re.search("_tpr_test", file)]
    fpr_file = [path + "/" + file for file in os.listdir(path) if re.search("_fpr_test", file)]

    fpr = pandas.read_csv(fpr_file[0], header=None)
    tpr = pandas.read_csv(tpr_file[0], header=None)

    fpr = helper_functions.drop_useless_column(fpr)
    tpr = helper_functions.drop_useless_column(tpr)

    auc = merged_files_limma.auc_test.values[i]
    model = merged_files_limma.model.values[i]

    plt.plot(fpr[1], tpr[1], label= f"{model} ({auc})")
plt.legend(loc='best')
plt.savefig("ROC_curve_final_test_limma_raw.pdf", dpi=300)
