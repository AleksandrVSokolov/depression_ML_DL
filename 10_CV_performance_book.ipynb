# %% [markdown]
# ### Evaluating Performance of 10 CV for ML models (significant CpGs limma)

# %%
import os
os.makedirs("10_CV_Results_MAIN", exist_ok=True)

# %%
import os
import pandas
from HelperScriptsPY import helper_functions

base_dir = "10_CV_ML_Limma_CpGs"
model_folders = [base_dir + "/" + x for x in os.listdir(base_dir)]

performance_lists = []

for model_folder in model_folders:
    CV_folders = [model_folder + "/" + x for x in os.listdir(model_folder)]
    analysis_files = [x + "/" + i + "/average_stats.csv" for x in CV_folders for i in os.listdir(x)]

    for path in analysis_files:
        dataset = pandas.read_csv(path)
        dataset["path"] = path
        performance_lists.append(dataset)


performance_lists = pandas.concat(performance_lists)
performance_lists =  performance_lists.groupby(['model', "mval"])[["accuracy_train", "accuracy_test", "auc_train", "auc_test"]].mean()
performance_lists = pandas.DataFrame(performance_lists)
performance_lists["CpG_type"] = "Top 200 Limma"
performance_lists.to_csv("10_CV_Results_MAIN/10_CV_ML_Signif_CpGs_Limma_performance.csv")
performance_lists = performance_lists.sort_values(by=["model"], ascending=False)
performance_lists
# Out:
#                                 accuracy_train  accuracy_test  auc_train
# model                  mval
# SVM_c_RBF_15           Mval           0.907749       0.570541   0.971452  \
#                        Betaval        0.590406       0.590406   0.779803
# SVM_c                  Mval           0.833364       0.522878   0.881809
#                        Betaval        0.765652       0.558795   0.827142
# RidgeLogisticRegr      Mval           0.822909       0.527060   0.895468
#                        Betaval        0.741421       0.568573   0.806776
# RandomForest           Betaval        1.000000       0.590283   1.000000
#                        Mval           1.000000       0.595941   1.000000
# LogisticRegr           Mval           0.823862       0.519619   0.896686
#                        Betaval        0.821464       0.526691   0.895572
# Lasso_classifier       Mval           0.822017       0.533579   0.893588
#                        Betaval        0.731673       0.552583   0.798157
# Elastic_net_classifier Mval           0.819895       0.523801   0.891003
#                        Betaval        0.733887       0.561808   0.799835
# DecisionTree           Mval           1.000000       0.533149   1.000000
#                        Betaval        1.000000       0.524785   1.000000
# AdaBoost               Mval           0.846556       0.539914   0.930105
#                        Betaval        0.845141       0.547048   0.929551
#
#                                 auc_test       CpG_type
# model                  mval
# SVM_c_RBF_15           Mval     0.547009  Top 200 Limma
#                        Betaval  0.533235  Top 200 Limma
# SVM_c                  Mval     0.500493  Top 200 Limma
#                        Betaval  0.519934  Top 200 Limma
# RidgeLogisticRegr      Mval     0.507232  Top 200 Limma
#                        Betaval  0.531159  Top 200 Limma
# RandomForest           Betaval  0.565948  Top 200 Limma
#                        Mval     0.568516  Top 200 Limma
# LogisticRegr           Mval     0.498274  Top 200 Limma
#                        Betaval  0.503807  Top 200 Limma
# Lasso_classifier       Mval     0.508332  Top 200 Limma
#                        Betaval  0.513386  Top 200 Limma
# Elastic_net_classifier Mval     0.504311  Top 200 Limma
#                        Betaval  0.523116  Top 200 Limma
# DecisionTree           Mval     0.519573  Top 200 Limma
#                        Betaval  0.508799  Top 200 Limma
# AdaBoost               Mval     0.521883  Top 200 Limma
#                        Betaval  0.531638  Top 200 Limma

# %% [markdown]
# ### Evaluating Performance of 10 CV for ML models (consistent CpGs (pre-selected))

# %%
import os
import pandas
from HelperScriptsPY import helper_functions

base_dir = "10_CV_ML_200_ALL_consistent_CpGs"
model_folders = [base_dir + "/" + x for x in os.listdir(base_dir)]

performance_lists = []

for model_folder in model_folders:
    CV_folders = [model_folder + "/" + x for x in os.listdir(model_folder)]
    analysis_files = [x + "/" + i + "/average_stats.csv" for x in CV_folders for i in os.listdir(x)]

    for path in analysis_files:
        dataset = pandas.read_csv(path)
        dataset["path"] = path
        performance_lists.append(dataset)


performance_lists = pandas.concat(performance_lists)
performance_lists =  performance_lists.groupby(['model', "mval"])[["accuracy_train", "accuracy_test", "auc_train", "auc_test"]].mean()
performance_lists = pandas.DataFrame(performance_lists)
performance_lists["CpG_type"] = "Top 200 Consistent (Pre-selected)"
performance_lists.to_csv("10_CV_Results_MAIN/10_CV_ML_Consistent_CpGs_performance.csv")
performance_lists = performance_lists.sort_values(by=["model"], ascending=False)
performance_lists
# Out:
#                                 accuracy_train  accuracy_test  auc_train
# model                  mval
# SVM_c_RBF_15           Mval           0.889545       0.686900   0.956972  \
#                        Betaval        0.590406       0.590406   0.767344
# SVM_c                  Mval           0.797940       0.647970   0.845197
#                        Betaval        0.707011       0.653260   0.773472
# RidgeLogisticRegr      Mval           0.784010       0.659164   0.852554
#                        Betaval        0.696986       0.652276   0.760150
# RandomForest           Betaval        1.000000       0.647847   1.000000
#                        Mval           1.000000       0.648278   1.000000
# LogisticRegr           Mval           0.784963       0.648278   0.854905
#                        Betaval        0.784994       0.647540   0.854168
# Lasso_classifier       Mval           0.784256       0.651353   0.851711
#                        Betaval        0.659071       0.603383   0.720688
# Elastic_net_classifier Mval           0.786624       0.657872   0.852811
#                        Betaval        0.676415       0.627122   0.743757
# DecisionTree           Mval           1.000000       0.541882   1.000000
#                        Betaval        1.000000       0.541451   1.000000
# AdaBoost               Mval           0.816759       0.605228   0.904226
#                        Betaval        0.816574       0.605289   0.905355
#
#                                 auc_test                           CpG_type
# model                  mval
# SVM_c_RBF_15           Mval     0.724988  Top 200 Consistent (Pre-selected)
#                        Betaval  0.682063  Top 200 Consistent (Pre-selected)
# SVM_c                  Mval     0.686429  Top 200 Consistent (Pre-selected)
#                        Betaval  0.685321  Top 200 Consistent (Pre-selected)
# RidgeLogisticRegr      Mval     0.693886  Top 200 Consistent (Pre-selected)
#                        Betaval  0.687335  Top 200 Consistent (Pre-selected)
# RandomForest           Betaval  0.671521  Top 200 Consistent (Pre-selected)
#                        Mval     0.673649  Top 200 Consistent (Pre-selected)
# LogisticRegr           Mval     0.682650  Top 200 Consistent (Pre-selected)
#                        Betaval  0.682478  Top 200 Consistent (Pre-selected)
# Lasso_classifier       Mval     0.686281  Top 200 Consistent (Pre-selected)
#                        Betaval  0.604185  Top 200 Consistent (Pre-selected)
# Elastic_net_classifier Mval     0.689217  Top 200 Consistent (Pre-selected)
#                        Betaval  0.644021  Top 200 Consistent (Pre-selected)
# DecisionTree           Mval     0.528252  Top 200 Consistent (Pre-selected)
#                        Betaval  0.527283  Top 200 Consistent (Pre-selected)
# AdaBoost               Mval     0.617535  Top 200 Consistent (Pre-selected)
#                        Betaval  0.619474  Top 200 Consistent (Pre-selected)

# %% [markdown]
# ### Performance of Ridge regression, Lasso, and Elastic net classifiers from top 10K limma CpGs

# %%
import os
import pandas
from HelperScriptsPY import helper_functions

base_dir = "10_CV_ML_10K_Limma"
model_folders = [base_dir + "/" + x for x in os.listdir(base_dir)]

performance_lists = []

for model_folder in model_folders:
    CV_folders = [model_folder + "/" + x for x in os.listdir(model_folder)]
    analysis_files = [x + "/" + i + "/average_stats.csv" for x in CV_folders for i in os.listdir(x)]

    for path in analysis_files:
        dataset = pandas.read_csv(path)
        dataset["path"] = path
        performance_lists.append(dataset)


performance_lists = pandas.concat(performance_lists)
performance_lists =  performance_lists.groupby(['model', "mval"])[["accuracy_train", "accuracy_test", "auc_train", "auc_test"]].mean()
performance_lists = pandas.DataFrame(performance_lists)
performance_lists["CpG_type"] = "Top 10K Limma"
performance_lists.to_csv("10_CV_Results_MAIN/10_CV_ML_10K_Limma_performance.csv")
performance_lists = performance_lists.sort_values(by=["model"], ascending=False)
performance_lists
# Out:
#                                 accuracy_train  accuracy_test  auc_train
# model                  mval
# RidgeLogisticRegr      Betaval        0.996710       0.489545   0.999996  \
#                        Mval           1.000000       0.449754   1.000000
# Lasso_classifier       Betaval        0.921925       0.518389   0.980719
#                        Mval           0.999969       0.475461   1.000000
# Elastic_net_classifier Betaval        0.954766       0.526876   0.994026
#                        Mval           1.000000       0.469004   1.000000
#
#                                 auc_test       CpG_type
# model                  mval
# RidgeLogisticRegr      Betaval  0.437396  Top 10K Limma
#                        Mval     0.403076  Top 10K Limma
# Lasso_classifier       Betaval  0.468664  Top 10K Limma
#                        Mval     0.424671  Top 10K Limma
# Elastic_net_classifier Betaval  0.475504  Top 10K Limma
#                        Mval     0.418782  Top 10K Limma

# %% [markdown]
# ### Performance of 10 CV JointAE-classifier (limma and consistent)

# %%
import os
import pandas
from HelperScriptsPY import helper_functions

base_dir = "10CV_DNN/10_CV_JointAE"
CV_folders = [base_dir + "/" + x for x in os.listdir(base_dir) if os.path.isdir(base_dir + "/" + x)]
performance_lists = []

for x in CV_folders:
    sub_folder = os.listdir(x)[0]
    path = x + "/" + sub_folder + "/" + "average_stats.csv"
    dataset = pandas.read_csv(path)
    dataset = helper_functions.drop_useless_column(dataset)
    performance_lists.append(dataset)

performance_df = pandas.concat(performance_lists)
output_stats =  performance_df[["accuracy_train", "accuracy_test", "auc_train", "auc_test"]].mean()
output_stats = pandas.DataFrame(output_stats)
output_stats = output_stats.transpose()

output_stats_base_info = performance_df.drop(["accuracy_train",
                                       "accuracy_test", 
                                       "auc_train", 
                                       "auc_test",
                                       "roc_auc_plot_test"] , axis=1)
output_stats_base_info = output_stats_base_info.iloc[0]
output_stats_base_info = pandas.DataFrame(output_stats_base_info)
output_stats_base_info = output_stats_base_info.transpose()
output_stats = pandas.concat([output_stats_base_info, output_stats], axis=1)
output_stats["model"] = "JointAE-classifier"
output_stats.to_csv("10_CV_Results_MAIN/10_CV_JointAE.csv")
output_stats
# Out:
#                 model epochs total_folds batch_size  mval balance_alpha
# 0  JointAE-classifier   2000           3        128  Mval           0.1  \
#
#   cpg_type limma_features outer_cls_activ outer_ae_activ  ... learning_rate
# 0      ALL            200         sigmoid         linear  ...        0.0001  \
#
#   drop_rate     classif_loss_fun      recon_loss_fun batch_normal
# 0       0.1  binary_crossentropy  mean_squared_error           BN  \
#
#   kernel_regular accuracy_train  accuracy_test  auc_train  auc_test
# 0          l1_l2       0.925185       0.544895   0.915404  0.529039
#
# [1 rows x 21 columns]

# %%
import os
import pandas
from HelperScriptsPY import helper_functions

base_dir = "10CV_DNN/10_CV_JointAE_consistent"
CV_folders = [base_dir + "/" + x for x in os.listdir(base_dir) if os.path.isdir(base_dir + "/" + x)]
performance_lists = []

for x in CV_folders:
    sub_folder = os.listdir(x)[0]
    path = x + "/" + sub_folder + "/" + "average_stats.csv"
    dataset = pandas.read_csv(path)
    dataset = helper_functions.drop_useless_column(dataset)
    performance_lists.append(dataset)

performance_df = pandas.concat(performance_lists)
output_stats =  performance_df[["accuracy_train", "accuracy_test", "auc_train", "auc_test"]].mean()
output_stats = pandas.DataFrame(output_stats)
output_stats = output_stats.transpose()

output_stats_base_info = performance_df.drop(["accuracy_train",
                                       "accuracy_test", 
                                       "auc_train", 
                                       "auc_test",
                                       "roc_auc_plot_test"] , axis=1)
output_stats_base_info = output_stats_base_info.iloc[0]
output_stats_base_info = pandas.DataFrame(output_stats_base_info)
output_stats_base_info = output_stats_base_info.transpose()
output_stats = pandas.concat([output_stats_base_info, output_stats], axis=1)
output_stats["model"] = "JointAE-classifier"
output_stats.to_csv("10_CV_Results_MAIN/10_CV_JointAE_consistent.csv")
output_stats
# Out:
#                 model epochs total_folds batch_size  mval balance_alpha
# 0  JointAE-classifier   2000           3        128  Mval           0.1  \
#
#                           cpg_type limma_features outer_cls_activ
# 0  Top_200_all_consistent_CpGs.txt            200         sigmoid  \
#
#   outer_ae_activ  ... learning_rate drop_rate     classif_loss_fun
# 0         linear  ...        0.0001       0.1  binary_crossentropy  \
#
#        recon_loss_fun batch_normal kernel_regular accuracy_train
# 0  mean_squared_error           BN          l1_l2       0.892651  \
#
#    accuracy_test  auc_train  auc_test
# 0       0.664084   0.875238  0.678125
#
# [1 rows x 21 columns]

# %% [markdown]
# ### Performance of 10CV JointVAE-classifier (limma and consistent)

# %%
import os
import pandas
from HelperScriptsPY import helper_functions

base_dir = "10CV_DNN/10_CV_JointVAE"
CV_folders = [base_dir + "/" + x for x in os.listdir(base_dir) if os.path.isdir(base_dir + "/" + x)]
performance_lists = []

for x in CV_folders:
    sub_folder = os.listdir(x)[0]
    path = x + "/" + sub_folder + "/" + "average_stats.csv"
    dataset = pandas.read_csv(path)
    dataset = helper_functions.drop_useless_column(dataset)
    performance_lists.append(dataset)

performance_df = pandas.concat(performance_lists)
output_stats =  performance_df[["accuracy_train", "accuracy_test", "auc_train", "auc_test"]].mean()
output_stats = pandas.DataFrame(output_stats)
output_stats = output_stats.transpose()

output_stats_base_info = performance_df.drop(["accuracy_train",
                                       "accuracy_test", 
                                       "auc_train", 
                                       "auc_test",
                                       "roc_auc_plot_test"] , axis=1)
output_stats_base_info = output_stats_base_info.iloc[0]
output_stats_base_info = pandas.DataFrame(output_stats_base_info)
output_stats_base_info = output_stats_base_info.transpose()
output_stats = pandas.concat([output_stats_base_info, output_stats], axis=1)
output_stats["model"] = "JointVAE-classifier"
output_stats.to_csv("10_CV_Results_MAIN/10_CV_JointVAE.csv")
output_stats
# Out:
#                  model epochs total_folds batch_size  mval balance_alpha
# 0  JointVAE-classifier   2250           3        128  Mval           1.0  \
#
#   cpg_type limma_features outer_cls_activ outer_ae_activ  ... learning_rate
# 0      ALL            200            tanh         linear  ...        0.0001  \
#
#   drop_rate classif_loss_fun      recon_loss_fun batch_normal kernel_regular
# 0       0.1    squared_hinge  mean_squared_error           BN          l1_l2  \
#
#   accuracy_train  accuracy_test  auc_train  auc_test
# 0       0.972325       0.542497   0.970598  0.532967
#
# [1 rows x 21 columns]

# %%
import os
import pandas
from HelperScriptsPY import helper_functions

base_dir = "10CV_DNN/10_CV_JointVAE_consistent"
CV_folders = [base_dir + "/" + x for x in os.listdir(base_dir) if os.path.isdir(base_dir + "/" + x)]
performance_lists = []

for x in CV_folders:
    sub_folder = os.listdir(x)[0]
    path = x + "/" + sub_folder + "/" + "average_stats.csv"
    dataset = pandas.read_csv(path)
    dataset = helper_functions.drop_useless_column(dataset)
    performance_lists.append(dataset)

performance_df = pandas.concat(performance_lists)
output_stats =  performance_df[["accuracy_train", "accuracy_test", "auc_train", "auc_test"]].mean()
output_stats = pandas.DataFrame(output_stats)
output_stats = output_stats.transpose()

output_stats_base_info = performance_df.drop(["accuracy_train",
                                       "accuracy_test", 
                                       "auc_train", 
                                       "auc_test",
                                       "roc_auc_plot_test"] , axis=1)
output_stats_base_info = output_stats_base_info.iloc[0]
output_stats_base_info = pandas.DataFrame(output_stats_base_info)
output_stats_base_info = output_stats_base_info.transpose()
output_stats = pandas.concat([output_stats_base_info, output_stats], axis=1)
output_stats["model"]= "JointVAE-classifier"
output_stats.to_csv("10_CV_Results_MAIN/10_CV_JointVAE_consistent.csv")
output_stats
# Out:
#                  model epochs total_folds batch_size  mval balance_alpha
# 0  JointVAE-classifier   2250           3        128  Mval           1.0  \
#
#                           cpg_type limma_features outer_cls_activ
# 0  Top_200_all_consistent_CpGs.txt            200            tanh  \
#
#   outer_ae_activ  ... learning_rate drop_rate classif_loss_fun
# 0         linear  ...        0.0001       0.1    squared_hinge  \
#
#        recon_loss_fun batch_normal kernel_regular accuracy_train
# 0  mean_squared_error           BN          l1_l2       0.967312  \
#
#    accuracy_test  auc_train  auc_test
# 0       0.634194   0.964996  0.659609
#
# [1 rows x 21 columns]

# %% [markdown]
# ### Performance of 10CV Small DNN (limma and consistent)

# %%
import os
import pandas
from HelperScriptsPY import helper_functions

base_dir = "10CV_DNN/10_CV_SmallDNN"
CV_folders = [base_dir + "/" + x for x in os.listdir(base_dir) if os.path.isdir(base_dir + "/" + x)]
performance_lists = []

for x in CV_folders:
    sub_folder = os.listdir(x)[0]
    path = x + "/" + sub_folder + "/" + "average_stats.csv"
    dataset = pandas.read_csv(path)
    dataset = helper_functions.drop_useless_column(dataset)
    performance_lists.append(dataset)

performance_df = pandas.concat(performance_lists)
output_stats =  performance_df[["accuracy_train", "accuracy_test", "auc_train", "auc_test"]].mean()
output_stats = pandas.DataFrame(output_stats)
output_stats = output_stats.transpose()

output_stats_base_info = performance_df.drop(["accuracy_train",
                                       "accuracy_test", 
                                       "auc_train", 
                                       "auc_test"] , axis=1)
output_stats_base_info = output_stats_base_info.iloc[0]
output_stats_base_info = pandas.DataFrame(output_stats_base_info)
output_stats_base_info = output_stats_base_info.transpose()
output_stats = pandas.concat([output_stats_base_info, output_stats], axis=1)
output_stats["model"] = "DNN classifier"
output_stats.to_csv("10_CV_Results_MAIN/10_CV_SmallDNN.csv")
output_stats
# Out:
#             model epochs total_folds batch_size  mval cpg_type limma_features
# 0  DNN classifier   1000           3        128  Mval      ALL            200  \
#
#   outer_cls_activ inner_act learning_rate     classif_loss_fun
# 0         sigmoid      relu        0.0001  binary_crossentropy  \
#
#   roc_auc_plot_test  accuracy_train  accuracy_test  auc_train  auc_test
# 0          0.539392        0.999692       0.546433        1.0   0.53781

# %%
import os
import pandas
from HelperScriptsPY import helper_functions

base_dir = "10CV_DNN/10_CV_SmallDNN_consistent"
CV_folders = [base_dir + "/" + x for x in os.listdir(base_dir) if os.path.isdir(base_dir + "/" + x)]
performance_lists = []

for x in CV_folders:
    sub_folder = os.listdir(x)[0]
    path = x + "/" + sub_folder + "/" + "average_stats.csv"
    dataset = pandas.read_csv(path)
    dataset = helper_functions.drop_useless_column(dataset)
    performance_lists.append(dataset)

performance_df = pandas.concat(performance_lists)
output_stats =  performance_df[["accuracy_train", "accuracy_test", "auc_train", "auc_test"]].mean()
output_stats = pandas.DataFrame(output_stats)
output_stats = output_stats.transpose()

output_stats_base_info = performance_df.drop(["accuracy_train",
                                       "accuracy_test", 
                                       "auc_train", 
                                       "auc_test"] , axis=1)
output_stats_base_info = output_stats_base_info.iloc[0]
output_stats_base_info = pandas.DataFrame(output_stats_base_info)
output_stats_base_info = output_stats_base_info.transpose()
output_stats = pandas.concat([output_stats_base_info, output_stats], axis=1)
output_stats["model"] = "DNN classifier"
output_stats.to_csv("10_CV_Results_MAIN/10_CV_SmallDNN_consistent.csv")
output_stats
# Out:
#             model epochs total_folds batch_size  mval
# 0  DNN classifier   1000           3        128  Mval  \
#
#                           cpg_type limma_features outer_cls_activ inner_act
# 0  Top_200_all_consistent_CpGs.txt            200         sigmoid      relu  \
#
#   learning_rate     classif_loss_fun roc_auc_plot_test  accuracy_train
# 0        0.0001  binary_crossentropy          0.678233        0.999385  \
#
#    accuracy_test  auc_train  auc_test
# 0       0.636777   0.999987  0.671531

# %% [markdown]
# ### Generating Final tables

# %%
import os
import pandas
import re
from HelperScriptsPY import helper_functions

base_dir = "10_CV_Results_MAIN"
ml_files = [base_dir + "/" + x for x in os.listdir(base_dir) if re.search("ML", x)]

merged_files = []

for x in ml_files:
    dataset = pandas.read_csv(x)
    dataset = helper_functions.drop_useless_column(dataset)
    dataset.replace({'model': {
        "SVM_c_RBF_15": "SVM (RBF kernel)",
        "SVM_c": "SVM (Linear kernel)",
        "RidgeLogisticRegr": "Logistic regression ('L2')",
        "RandomForest": "Random forest",
        "LogisticRegr": "Logistic regression (no regularization)",
        "Lasso_classifier": "Logistic regression ('L1')",
        "Elastic_net_classifier": "Logistic regression ('L1L2'/Elastic net)",
        "DecisionTree": "Decision tree"
    }}, inplace=True)
    merged_files.append(dataset)
merged_files = pandas.concat(merged_files)
merged_files.columns = ["Model", 
                        "Methylation value", 
                        "10 CV accuracy (train)", 
                        "10 CV accuracy (hold-out)", 
                        "10 CV AUC (train)",
                        "10 CV AUC (hold-out)",
                        "Selected CpGs (features)"]
merged_files = merged_files.reset_index(drop=True)
merged_files.loc[:, merged_files.dtypes != "object"] = merged_files.loc[:, merged_files.dtypes != "object"].round(decimals=3)
merged_files
# Out:
#                                        Model Methylation value
# 0                                   AdaBoost           Betaval  \
# 1                                   AdaBoost              Mval
# 2                              Decision tree           Betaval
# 3                              Decision tree              Mval
# 4   Logistic regression ('L1L2'/Elastic net)           Betaval
# 5   Logistic regression ('L1L2'/Elastic net)              Mval
# 6                 Logistic regression ('L1')           Betaval
# 7                 Logistic regression ('L1')              Mval
# 8    Logistic regression (no regularization)           Betaval
# 9    Logistic regression (no regularization)              Mval
# 10                             Random forest           Betaval
# 11                             Random forest              Mval
# 12                Logistic regression ('L2')           Betaval
# 13                Logistic regression ('L2')              Mval
# 14                       SVM (Linear kernel)           Betaval
# 15                       SVM (Linear kernel)              Mval
# 16                          SVM (RBF kernel)           Betaval
# 17                          SVM (RBF kernel)              Mval
# 18                                  AdaBoost           Betaval
# 19                                  AdaBoost              Mval
# 20                             Decision tree           Betaval
# 21                             Decision tree              Mval
# 22  Logistic regression ('L1L2'/Elastic net)           Betaval
# 23  Logistic regression ('L1L2'/Elastic net)              Mval
# 24                Logistic regression ('L1')           Betaval
# 25                Logistic regression ('L1')              Mval
# 26   Logistic regression (no regularization)           Betaval
# 27   Logistic regression (no regularization)              Mval
# 28                             Random forest           Betaval
# 29                             Random forest              Mval
# 30                Logistic regression ('L2')           Betaval
# 31                Logistic regression ('L2')              Mval
# 32                       SVM (Linear kernel)           Betaval
# 33                       SVM (Linear kernel)              Mval
# 34                          SVM (RBF kernel)           Betaval
# 35                          SVM (RBF kernel)              Mval
# 36  Logistic regression ('L1L2'/Elastic net)           Betaval
# 37  Logistic regression ('L1L2'/Elastic net)              Mval
# 38                Logistic regression ('L1')           Betaval
# 39                Logistic regression ('L1')              Mval
# 40                Logistic regression ('L2')           Betaval
# 41                Logistic regression ('L2')              Mval
#
#     10 CV accuracy (train)  10 CV accuracy (hold-out)  10 CV AUC (train)
# 0                    0.817                      0.605              0.905  \
# 1                    0.817                      0.605              0.904
# 2                    1.000                      0.541              1.000
# 3                    1.000                      0.542              1.000
# 4                    0.676                      0.627              0.744
# 5                    0.787                      0.658              0.853
# 6                    0.659                      0.603              0.721
# 7                    0.784                      0.651              0.852
# 8                    0.785                      0.648              0.854
# 9                    0.785                      0.648              0.855
# 10                   1.000                      0.648              1.000
# 11                   1.000                      0.648              1.000
# 12                   0.697                      0.652              0.760
# 13                   0.784                      0.659              0.853
# 14                   0.707                      0.653              0.773
# 15                   0.798                      0.648              0.845
# 16                   0.590                      0.590              0.767
# 17                   0.890                      0.687              0.957
# 18                   0.845                      0.547              0.930
# 19                   0.847                      0.540              0.930
# 20                   1.000                      0.525              1.000
# 21                   1.000                      0.533              1.000
# 22                   0.734                      0.562              0.800
# 23                   0.820                      0.524              0.891
# 24                   0.732                      0.553              0.798
# 25                   0.822                      0.534              0.894
# 26                   0.821                      0.527              0.896
# 27                   0.824                      0.520              0.897
# 28                   1.000                      0.590              1.000
# 29                   1.000                      0.596              1.000
# 30                   0.741                      0.569              0.807
# 31                   0.823                      0.527              0.895
# 32                   0.766                      0.559              0.827
# 33                   0.833                      0.523              0.882
# 34                   0.590                      0.590              0.780
# 35                   0.908                      0.571              0.971
# 36                   0.955                      0.527              0.994
# 37                   1.000                      0.469              1.000
# 38                   0.922                      0.518              0.981
# 39                   1.000                      0.475              1.000
# 40                   0.997                      0.490              1.000
# 41                   1.000                      0.450              1.000
#
#     10 CV AUC (hold-out)           Selected CpGs (features)
# 0                  0.619  Top 200 Consistent (Pre-selected)
# 1                  0.618  Top 200 Consistent (Pre-selected)
# 2                  0.527  Top 200 Consistent (Pre-selected)
# 3                  0.528  Top 200 Consistent (Pre-selected)
# 4                  0.644  Top 200 Consistent (Pre-selected)
# 5                  0.689  Top 200 Consistent (Pre-selected)
# 6                  0.604  Top 200 Consistent (Pre-selected)
# 7                  0.686  Top 200 Consistent (Pre-selected)
# 8                  0.682  Top 200 Consistent (Pre-selected)
# 9                  0.683  Top 200 Consistent (Pre-selected)
# 10                 0.672  Top 200 Consistent (Pre-selected)
# 11                 0.674  Top 200 Consistent (Pre-selected)
# 12                 0.687  Top 200 Consistent (Pre-selected)
# 13                 0.694  Top 200 Consistent (Pre-selected)
# 14                 0.685  Top 200 Consistent (Pre-selected)
# 15                 0.686  Top 200 Consistent (Pre-selected)
# 16                 0.682  Top 200 Consistent (Pre-selected)
# 17                 0.725  Top 200 Consistent (Pre-selected)
# 18                 0.532                      Top 200 Limma
# 19                 0.522                      Top 200 Limma
# 20                 0.509                      Top 200 Limma
# 21                 0.520                      Top 200 Limma
# 22                 0.523                      Top 200 Limma
# 23                 0.504                      Top 200 Limma
# 24                 0.513                      Top 200 Limma
# 25                 0.508                      Top 200 Limma
# 26                 0.504                      Top 200 Limma
# 27                 0.498                      Top 200 Limma
# 28                 0.566                      Top 200 Limma
# 29                 0.569                      Top 200 Limma
# 30                 0.531                      Top 200 Limma
# 31                 0.507                      Top 200 Limma
# 32                 0.520                      Top 200 Limma
# 33                 0.500                      Top 200 Limma
# 34                 0.533                      Top 200 Limma
# 35                 0.547                      Top 200 Limma
# 36                 0.476                      Top 10K Limma
# 37                 0.419                      Top 10K Limma
# 38                 0.469                      Top 10K Limma
# 39                 0.425                      Top 10K Limma
# 40                 0.437                      Top 10K Limma
# 41                 0.403                      Top 10K Limma

# %%
import os
import pandas
import re
from HelperScriptsPY import helper_functions

base_dir = "10_CV_Results_MAIN"
ml_files = [base_dir + "/" + x for x in os.listdir(base_dir) if not re.search("ML", x) and not re.search(".xlsx", x)]

merged_files_DNN = []

for x in ml_files:
    dataset = pandas.read_csv(x)
    dataset = helper_functions.drop_useless_column(dataset)
    dataset = dataset[["model", 
                       "mval",
                       "accuracy_train",
                       "accuracy_test",
                       "auc_train",
                       "auc_test",
                       "cpg_type"]]
    
    dataset.replace({'cpg_type': {
        "ALL":"Top 200 Limma",
        "Top_200_all_consistent_CpGs.txt": "Top 200 Consistent (Pre-selected)"
    }}, inplace=True)

    merged_files_DNN.append(dataset)
    
merged_files_DNN = pandas.concat(merged_files_DNN)
merged_files_DNN.columns = ["Model", 
                        "Methylation value", 
                        "10 CV accuracy (train)", 
                        "10 CV accuracy (hold-out)", 
                        "10 CV AUC (train)",
                        "10 CV AUC (hold-out)",
                        "Selected CpGs (features)"]
merged_files_DNN = merged_files_DNN.reset_index(drop=True)
merged_files_DNN.loc[:, merged_files_DNN.dtypes != "object"] = merged_files_DNN.loc[:, merged_files_DNN.dtypes != "object"].round(decimals=3)
merged_files_DNN = merged_files_DNN.sort_values(by=["Selected CpGs (features)", "Model"], ascending=True)
merged_files_DNN
# Out:
#                  Model Methylation value  10 CV accuracy (train)
# 4       DNN classifier              Mval                   0.999  \
# 5   JointAE-classifier              Mval                   0.893
# 1  JointVAE-classifier              Mval                   0.967
# 3       DNN classifier              Mval                   1.000
# 2   JointAE-classifier              Mval                   0.925
# 0  JointVAE-classifier              Mval                   0.972
#
#    10 CV accuracy (hold-out)  10 CV AUC (train)  10 CV AUC (hold-out)
# 4                      0.637              1.000                 0.672  \
# 5                      0.664              0.875                 0.678
# 1                      0.634              0.965                 0.660
# 3                      0.546              1.000                 0.538
# 2                      0.545              0.915                 0.529
# 0                      0.542              0.971                 0.533
#
#             Selected CpGs (features)
# 4  Top 200 Consistent (Pre-selected)
# 5  Top 200 Consistent (Pre-selected)
# 1  Top 200 Consistent (Pre-selected)
# 3                      Top 200 Limma
# 2                      Top 200 Limma
# 0                      Top 200 Limma

# %%
final_performance_CV10 = pandas.concat([merged_files, merged_files_DNN])
final_performance_CV10 = final_performance_CV10.sort_values(by=["Selected CpGs (features)", "Model"], ascending=True)
final_performance_CV10 = final_performance_CV10.reset_index(drop=True)
final_performance_CV10.to_excel("10_CV_Results_MAIN/Model_performance_10CV.xlsx", index=False)
final_performance_CV10
# Out:
#                                        Model Methylation value
# 0                 Logistic regression ('L1')           Betaval  \
# 1                 Logistic regression ('L1')              Mval
# 2   Logistic regression ('L1L2'/Elastic net)           Betaval
# 3   Logistic regression ('L1L2'/Elastic net)              Mval
# 4                 Logistic regression ('L2')           Betaval
# 5                 Logistic regression ('L2')              Mval
# 6                                   AdaBoost           Betaval
# 7                                   AdaBoost              Mval
# 8                             DNN classifier              Mval
# 9                              Decision tree           Betaval
# 10                             Decision tree              Mval
# 11                        JointAE-classifier              Mval
# 12                       JointVAE-classifier              Mval
# 13                Logistic regression ('L1')           Betaval
# 14                Logistic regression ('L1')              Mval
# 15  Logistic regression ('L1L2'/Elastic net)           Betaval
# 16  Logistic regression ('L1L2'/Elastic net)              Mval
# 17                Logistic regression ('L2')           Betaval
# 18                Logistic regression ('L2')              Mval
# 19   Logistic regression (no regularization)           Betaval
# 20   Logistic regression (no regularization)              Mval
# 21                             Random forest           Betaval
# 22                             Random forest              Mval
# 23                       SVM (Linear kernel)           Betaval
# 24                       SVM (Linear kernel)              Mval
# 25                          SVM (RBF kernel)           Betaval
# 26                          SVM (RBF kernel)              Mval
# 27                                  AdaBoost           Betaval
# 28                                  AdaBoost              Mval
# 29                            DNN classifier              Mval
# 30                             Decision tree           Betaval
# 31                             Decision tree              Mval
# 32                        JointAE-classifier              Mval
# 33                       JointVAE-classifier              Mval
# 34                Logistic regression ('L1')           Betaval
# 35                Logistic regression ('L1')              Mval
# 36  Logistic regression ('L1L2'/Elastic net)           Betaval
# 37  Logistic regression ('L1L2'/Elastic net)              Mval
# 38                Logistic regression ('L2')           Betaval
# 39                Logistic regression ('L2')              Mval
# 40   Logistic regression (no regularization)           Betaval
# 41   Logistic regression (no regularization)              Mval
# 42                             Random forest           Betaval
# 43                             Random forest              Mval
# 44                       SVM (Linear kernel)           Betaval
# 45                       SVM (Linear kernel)              Mval
# 46                          SVM (RBF kernel)           Betaval
# 47                          SVM (RBF kernel)              Mval
#
#     10 CV accuracy (train)  10 CV accuracy (hold-out)  10 CV AUC (train)
# 0                    0.922                      0.518              0.981  \
# 1                    1.000                      0.475              1.000
# 2                    0.955                      0.527              0.994
# 3                    1.000                      0.469              1.000
# 4                    0.997                      0.490              1.000
# 5                    1.000                      0.450              1.000
# 6                    0.817                      0.605              0.905
# 7                    0.817                      0.605              0.904
# 8                    0.999                      0.637              1.000
# 9                    1.000                      0.541              1.000
# 10                   1.000                      0.542              1.000
# 11                   0.893                      0.664              0.875
# 12                   0.967                      0.634              0.965
# 13                   0.659                      0.603              0.721
# 14                   0.784                      0.651              0.852
# 15                   0.676                      0.627              0.744
# 16                   0.787                      0.658              0.853
# 17                   0.697                      0.652              0.760
# 18                   0.784                      0.659              0.853
# 19                   0.785                      0.648              0.854
# 20                   0.785                      0.648              0.855
# 21                   1.000                      0.648              1.000
# 22                   1.000                      0.648              1.000
# 23                   0.707                      0.653              0.773
# 24                   0.798                      0.648              0.845
# 25                   0.590                      0.590              0.767
# 26                   0.890                      0.687              0.957
# 27                   0.845                      0.547              0.930
# 28                   0.847                      0.540              0.930
# 29                   1.000                      0.546              1.000
# 30                   1.000                      0.525              1.000
# 31                   1.000                      0.533              1.000
# 32                   0.925                      0.545              0.915
# 33                   0.972                      0.542              0.971
# 34                   0.732                      0.553              0.798
# 35                   0.822                      0.534              0.894
# 36                   0.734                      0.562              0.800
# 37                   0.820                      0.524              0.891
# 38                   0.741                      0.569              0.807
# 39                   0.823                      0.527              0.895
# 40                   0.821                      0.527              0.896
# 41                   0.824                      0.520              0.897
# 42                   1.000                      0.590              1.000
# 43                   1.000                      0.596              1.000
# 44                   0.766                      0.559              0.827
# 45                   0.833                      0.523              0.882
# 46                   0.590                      0.590              0.780
# 47                   0.908                      0.571              0.971
#
#     10 CV AUC (hold-out)           Selected CpGs (features)
# 0                  0.469                      Top 10K Limma
# 1                  0.425                      Top 10K Limma
# 2                  0.476                      Top 10K Limma
# 3                  0.419                      Top 10K Limma
# 4                  0.437                      Top 10K Limma
# 5                  0.403                      Top 10K Limma
# 6                  0.619  Top 200 Consistent (Pre-selected)
# 7                  0.618  Top 200 Consistent (Pre-selected)
# 8                  0.672  Top 200 Consistent (Pre-selected)
# 9                  0.527  Top 200 Consistent (Pre-selected)
# 10                 0.528  Top 200 Consistent (Pre-selected)
# 11                 0.678  Top 200 Consistent (Pre-selected)
# 12                 0.660  Top 200 Consistent (Pre-selected)
# 13                 0.604  Top 200 Consistent (Pre-selected)
# 14                 0.686  Top 200 Consistent (Pre-selected)
# 15                 0.644  Top 200 Consistent (Pre-selected)
# 16                 0.689  Top 200 Consistent (Pre-selected)
# 17                 0.687  Top 200 Consistent (Pre-selected)
# 18                 0.694  Top 200 Consistent (Pre-selected)
# 19                 0.682  Top 200 Consistent (Pre-selected)
# 20                 0.683  Top 200 Consistent (Pre-selected)
# 21                 0.672  Top 200 Consistent (Pre-selected)
# 22                 0.674  Top 200 Consistent (Pre-selected)
# 23                 0.685  Top 200 Consistent (Pre-selected)
# 24                 0.686  Top 200 Consistent (Pre-selected)
# 25                 0.682  Top 200 Consistent (Pre-selected)
# 26                 0.725  Top 200 Consistent (Pre-selected)
# 27                 0.532                      Top 200 Limma
# 28                 0.522                      Top 200 Limma
# 29                 0.538                      Top 200 Limma
# 30                 0.509                      Top 200 Limma
# 31                 0.520                      Top 200 Limma
# 32                 0.529                      Top 200 Limma
# 33                 0.533                      Top 200 Limma
# 34                 0.513                      Top 200 Limma
# 35                 0.508                      Top 200 Limma
# 36                 0.523                      Top 200 Limma
# 37                 0.504                      Top 200 Limma
# 38                 0.531                      Top 200 Limma
# 39                 0.507                      Top 200 Limma
# 40                 0.504                      Top 200 Limma
# 41                 0.498                      Top 200 Limma
# 42                 0.566                      Top 200 Limma
# 43                 0.569                      Top 200 Limma
# 44                 0.520                      Top 200 Limma
# 45                 0.500                      Top 200 Limma
# 46                 0.533                      Top 200 Limma
# 47                 0.547                      Top 200 Limma
